# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

from agents.DDPG import DDPG

from task import TestTask, Task, MyTask5, MyTask4

task = MyTask4(init_pose=[0,0,9,0,0,0], target_pos=[1,1,10])

agent = DDPG(task,
                 gamma=0.99,
                 UONoise_para={'theta': 0.25, 'mu': 0, 'sigma': 0.5},
                 tau = 0.01,
                 max_episode=2000,
                 batch_size=128,
                 memory_warmup=10240,
                 memory_size = 50000,
                 base_noice_scale = 1)
                 #max_explore_eps=000)
# Out:
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.

# %%
agent.train()
# Out:
#  iter 63202, ep 1617 ,score 31.384479, best 32.737027 time 4.979999999999982
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-bb73192c4e1d> in <module>()
# ----> 1 agent.train()
#
# ~\OneDrive\work\desktop_proj\RL-Quadcopter-2\agents\DDPG.py in train(self)
#     199         while self.curr_episode < self.max_episode:
#     200             #print('\riter {}, ep {}'.format(iteration, self.curr_episode), end='')
# --> 201             lst_act, state, reward, done = self.step()
#     202             episode_score += reward
#     203             episode_steps += 1
#
# ~\OneDrive\work\desktop_proj\RL-Quadcopter-2\agents\DDPG.py in step(self, state, is_train)
#     155             # Learn, if enough samples are available in memory
#     156             if len(self.memory) > self.memory_warmup:
# --> 157                 self.learn()
#     158         else:
# ...

# %%
agent.reset_episode()
# Out:
# array([-0.76159416, -0.76159416, -0.76159416,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.        ,  0.        , -0.76159416,
#        -0.76159416, -0.76159416,  0.        ,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.        , -0.76159416, -0.76159416,
#        -0.76159416,  0.        ,  0.        ,  0.        ,  0.        ,
#         0.        ,  0.        ])

# %%
agent.step()
# Out:
# (array([445.288932  , 458.96739714, 458.91125935, 460.        ]),
#  array([ 0.19001787,  0.29804777, -0.55975565,  0.92164194, -0.84683527,
#          0.        ,  0.98487971, -0.91015268,  0.        ,  0.27824003,
#          0.36680992, -0.58055588,  0.92869707, -0.85466023,  0.        ,
#          0.98421451, -0.89795608,  0.        ,  0.36559883,  0.43291099,
#         -0.60316361,  0.93508268, -0.86178673,  0.        ,  0.98353555,
#         -0.88439718,  0.        ]),
#  -3,
#  True)

# %%
import numpy as np
import csv
done = False
file_output = 'data.txt'                         # file name for saved results
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
agent.reset_episode()
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds, _, _, done = agent.step(is_train=False)        
 #       rotor_speeds = np.repeat(rotor_speeds, 4)
        to_write = [agent.task.sim.time] + list(agent.task.sim.pose) + list(agent.task.sim.v) + list(agent.task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %%
plt.plot(results['time'],np.pi - np.abs( np.array(results['phi']) - np.pi) , label='phi')
plt.plot(results['time'],np.pi - np.abs( np.array(results['theta']) - np.pi),  label='theta')
plt.plot(results['time'],np.pi - np.abs(  np.array(results['psi']) - np.pi), label='psi')
plt.legend()
_ = plt.ylim()

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %%
aa=np.array([1,5,0.4])

np.dot(np.tanh(aa),aa)
# Out:
# 5.913119762170831

# %%
np.dot(aa , aa)
# Out:
# 5

# %%
agent.task.env.observation_space.low
# Out:
# array([-1.2 , -0.07], dtype=float32)

# %%
import gym

# %%
env = gym.make('Pendulum-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
agent.reset_episode()
done = False
while not done:    
    agent.task.env.render()
    _,_,_, done = agent.step(is_train=False)

# %%
agent.task.env.close()

# %%
agent.task.env.reset()
# Out:
# array([ 0.11918024,  0.99287264, -0.99719959])
